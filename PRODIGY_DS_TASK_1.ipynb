# %% [markdown]
# <a href="https://colab.research.google.com/github/10bhakti/PRODIGY_DS_01/blob/main/PRODIGY_DS_TASK_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRODIGY_DS_TASK 1**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Downloading  the dataset
# !wget https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv -O titanic.csv

# Loading the dataset
df = pd.read_csv('titanic.csv')
print(df.columns)

# Proceeding with data
df['Age'].fillna(df['Age'].median(), inplace=True)
# If 'Embarked' exists:
if 'Embarked' in df.columns:
    df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)


df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

# If 'Embarked' exists:
if 'Embarked' in df.columns:
    df['Embarked'] = df['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# EDA PART
# 1--Age distribution
sns.histplot(df['Age'], bins=30)
plt.title('Age Distribution')
plt.show()

# 2--fare distribution
sns.histplot(df['Fare'], bins=30)
plt.title('Fare Distribution')
plt.show()

# 3--survival rate vs sex
sns.barplot(x='Sex', y='Survived', data=df)
plt.title('Survival Rate by Sex')
plt.show()

# 4--survival rate vs class
sns.barplot(x='Pclass', y='Survived', data=df)
plt.title('Survival Rate by Class')
plt.show()

#summary
print('--------------------------------------------------------------------------------')
print('                                                                                ')
print('Data Summary')
print('                                                                                ')
print(titanic.describe())
# Out:
# --2024-07-16 17:48:27--  https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Resolving web.stanford.edu (web.stanford.edu)... 171.67.215.200, 2607:f6d0:0:925a::ab43:d7c8
# Connecting to web.stanford.edu (web.stanford.edu)|171.67.215.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44225 (43K) [text/csv]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  43.19K  --.-KB/s    in 0.1s
#
# 2024-07-16 17:48:28 (310 KB/s) - ‘titanic.csv’ saved [44225/44225]
#
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')
# --------------------------------------------------------------------------------
#
# Data Summary
#
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# ...
